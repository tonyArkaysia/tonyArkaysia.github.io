# %%
import pandas as pd
# import requests
# import os
# from sqlalchemy import create_engine, func
# from config import pg_password

from pprint import pprint

from nba_api.stats.endpoints import scoreboard, scoreboardv2, playbyplay, playercareerstats, boxscoretraditionalv2
from nba_api.stats.static import players


# import seaborn as sns
import matplotlib.pyplot as plt

# %%
help(scoreboard)
# Out:
# Help on module nba_api.stats.endpoints.scoreboard in nba_api.stats.endpoints:
#
# NAME
#     nba_api.stats.endpoints.scoreboard
#
# CLASSES
#     nba_api.stats.endpoints._base.Endpoint(builtins.object)
#         Scoreboard
#
#     class Scoreboard(nba_api.stats.endpoints._base.Endpoint)
#      |  Scoreboard(day_offset='0', game_date='2023-12-13', league_id='00', proxy=None, headers=None, timeout=30, get_request=True)
#      |
#      |  Method resolution order:
#      |      Scoreboard
#      |      nba_api.stats.endpoints._base.Endpoint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, day_offset='0', game_date='2023-12-13', league_id='00', proxy=None, headers=None, timeout=30, get_request=True)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  get_request(self)
#      |
#      |  load_response(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  data_sets = None
#      |
#      |  endpoint = 'scoreboard'
#      |
#      |  expected_data = {'Available': ['GAME_ID', 'PT_AVAILABLE'], 'EastConfSt...
#      |
#      |  headers = None
#      |
#      |  nba_response = None
#      |
#      |  player_stats = None
#      |
#      |  team_stats = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from nba_api.stats.endpoints._base.Endpoint:
#      |
#      |  get_available_data(self)
#      |
#      |  get_data_frames(self)
#      |
#      |  get_dict(self)
#      |
#      |  get_json(self)
#      |
#      |  get_normalized_dict(self)
#      |
#      |  get_normalized_json(self)
#      |
#      |  get_request_url(self)
#      |
#      |  get_response(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from nba_api.stats.endpoints._base.Endpoint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from nba_api.stats.endpoints._base.Endpoint:
#      |
#      |  DataSet = <class 'nba_api.stats.endpoints._base.Endpoint.DataSet'>
#
# FILE
#     c:\users\2ainm\anaconda3\envs\pytf\lib\site-packages\nba_api\stats\endpoints\scoreboard.py

# %%
standings = scoreboard.Scoreboard(game_date='2023-12-13')

# %%
east_conf_standings_data = standings.get_data_frames()[4]
east_conf_standings_data
# Out:
#        TEAM_ID LEAGUE_ID SEASON_ID STANDINGSDATE CONFERENCE          TEAM   G  \
# 0   1610612738        00     22023    12/13/2023       East        Boston  22
# 1   1610612749        00     22023    12/13/2023       East     Milwaukee  23
# 2   1610612753        00     22023    12/13/2023       East       Orlando  23
# 3   1610612755        00     22023    12/13/2023       East  Philadelphia  22
# 4   1610612754        00     22023    12/13/2023       East       Indiana  21
# 5   1610612752        00     22023    12/13/2023       East      New York  22
# 6   1610612748        00     22023    12/13/2023       East         Miami  23
# 7   1610612751        00     22023    12/13/2023       East      Brooklyn  22
# 8   1610612739        00     22023    12/13/2023       East     Cleveland  24
# 9   1610612737        00     22023    12/13/2023       East       Atlanta  22
# 10  1610612761        00     22023    12/13/2023       East       Toronto  23
# 11  1610612741        00     22023    12/13/2023       East       Chicago  25
# 12  1610612766        00     22023    12/13/2023       East     Charlotte  21
# 13  1610612764        00     22023    12/13/2023       East    Washington  22
# 14  1610612765        00     22023    12/13/2023       East       Detroit  23
#
#      W   L  W_PCT HOME_RECORD ROAD_RECORD
# 0   17   5  0.773        11-0         6-5
# 1   16   7  0.696        11-2         5-5
# 2   16   7  0.696        11-2         5-5
# 3   15   7  0.682         9-3         6-4
# 4   13   8  0.619         7-5         6-3
# 5   13   9  0.591         7-3         6-6
# 6   13  10  0.565         5-4         8-6
# 7   12  10  0.545         8-5         4-5
# 8   13  11  0.542         6-6         7-5
# 9    9  13  0.409         3-7         6-6
# 10   9  14  0.391         6-6         3-8
# 11   9  16  0.360         7-7         2-9
# 12   7  14  0.333         4-8         3-6
# 13   3  19  0.136         1-7        2-12
# 14   2  21  0.087        1-11        1-10

# %%
west_conf_standings_data = standings.get_data_frames()[5]
west_conf_standings_data
# Out:
#        TEAM_ID LEAGUE_ID SEASON_ID STANDINGSDATE CONFERENCE           TEAM  \
# 0   1610612750        00     22023    12/13/2023       West      Minnesota
# 1   1610612760        00     22023    12/13/2023       West  Oklahoma City
# 2   1610612742        00     22023    12/13/2023       West         Dallas
# 3   1610612743        00     22023    12/13/2023       West         Denver
# 4   1610612758        00     22023    12/13/2023       West     Sacramento
# 5   1610612747        00     22023    12/13/2023       West    L.A. Lakers
# 6   1610612746        00     22023    12/13/2023       West    LA Clippers
# 7   1610612756        00     22023    12/13/2023       West        Phoenix
# 8   1610612745        00     22023    12/13/2023       West        Houston
# 9   1610612740        00     22023    12/13/2023       West    New Orleans
# 10  1610612744        00     22023    12/13/2023       West   Golden State
# 11  1610612762        00     22023    12/13/2023       West           Utah
# 12  1610612763        00     22023    12/13/2023       West        Memphis
# 13  1610612757        00     22023    12/13/2023       West       Portland
# 14  1610612759        00     22023    12/13/2023       West    San Antonio
#
#      G   W   L  W_PCT HOME_RECORD ROAD_RECORD
# 0   22  17   5  0.773        10-1         7-4
# 1   22  15   7  0.682         8-4         7-3
# 2   23  15   8  0.652         7-4         8-4
# 3   25  16   9  0.640         9-1         7-8
# 4   22  13   9  0.591         7-3         6-6
# 5   24  14  10  0.583        10-2         4-8
# 6   23  13  10  0.565         9-3         4-7
# 7   23  13  10  0.565         6-6         7-4
# 8   20  11   9  0.550        10-1         1-8
# 9   24  13  11  0.542         9-4         4-7
# 10  23  10  13  0.435         5-6         5-7
# 11  23   7  16  0.304         6-5        1-11
# 12  22   6  16  0.273        1-10         5-6
# 13  22   6  16  0.273         2-6        4-10
# 14  22   3  19  0.136        1-10         2-9

# %%
east_conf_standings_json = east_conf_standings_data.to_json(orient='records')
west_conf_standings_json = west_conf_standings_data.to_json(orient='records')

# %%
east_conf_standings_json
# Out:
# '[{"TEAM_ID":1610612738,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Boston","G":22,"W":17,"L":5,"W_PCT":0.773,"HOME_RECORD":"11-0","ROAD_RECORD":"6-5"},{"TEAM_ID":1610612749,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Milwaukee","G":23,"W":16,"L":7,"W_PCT":0.696,"HOME_RECORD":"11-2","ROAD_RECORD":"5-5"},{"TEAM_ID":1610612753,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Orlando","G":23,"W":16,"L":7,"W_PCT":0.696,"HOME_RECORD":"11-2","ROAD_RECORD":"5-5"},{"TEAM_ID":1610612755,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Philadelphia","G":22,"W":15,"L":7,"W_PCT":0.682,"HOME_RECORD":"9-3","ROAD_RECORD":"6-4"},{"TEAM_ID":1610612754,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Indiana","G":21,"W":13,"L":8,"W_PCT":0.619,"HOME_RECORD":"7-5","ROAD_RECORD":"6-3"},{"TEAM_ID":1610612752,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"New York","G":22,"W":13,"L":9,"W_PCT":0.591,"HOME_RECORD":"7-3","ROAD_RECORD":"6-6"},{"TEAM_ID":1610612748,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Miami","G":23,"W":13,"L":10,"W_PCT":0.565,"HOME_RECORD":"5-4","ROAD_RECORD":"8-6"},{"TEAM_ID":1610612751,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Brooklyn","G":22,"W":12,"L":10,"W_PCT":0.545,"HOME_RECORD":"8-5","ROAD_RECORD":"4-5"},{"TEAM_ID":1610612739,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Cleveland","G":24,"W":13,"L":11,"W_PCT":0.542,"HOME_RECORD":"6-6","ROAD_RECORD":"7-5"},{"TEAM_ID":1610612737,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Atlanta","G":22,"W":9,"L":13,"W_PCT":0.409,"HOME_RECORD":"3-7","ROAD_RECORD":"6-6"},{"TEAM_ID":1610612761,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Toronto","G":23,"W":9,"L":14,"W_PCT":0.391,"HOME_RECORD":"6-6","ROAD_RECORD":"3-8"},{"TEAM_ID":1610612741,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Chicago","G":25,"W":9,"L":16,"W_PCT":0.36,"HOME_RECORD":"7-7","ROAD_RECORD":"2-9"},{"TEAM_ID":1610612766,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Charlotte","G":21,"W":7,"L":14,"W_PCT":0.333,"HOME_RECORD":"4-8","ROAD_RECORD":"3-6"},{"TEAM_ID":1610612764,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Washington","G":22,"W":3,"L":19,"W_PCT":0.136,"HOME_RECORD":"1-7","ROAD_RECORD":"2-12"},{"TEAM_ID":1610612765,"LEAGUE_ID":"00","SEASON_ID":"22023","STANDINGSDATE":"12\\/13\\/2023","CONFERENCE":"East","TEAM":"Detroit","G":23,"W":2,"L":21,"W_PCT":0.087,"HOME_RECORD":"1-11","ROAD_RECORD":"1-10"}]'

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def index():
    # Pass the JSON data to the HTML template
    return render_template('isl-nba-main.html', east_conf_standings_json=east_conf_standings_json, west_conf_standings_json=west_conf_standings_json)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2023-12-13 18:58:00,906] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-8-92244a0b7ea5>", line 8, in index
#     return render_template('isl-nba-main.html', east_conf_standings_json=east_conf_standings_json, west_conf_standings_json=west_conf_standings_json)
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\flask\templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\jinja2\environment.py", line 930, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\jinja2\environment.py", line 883, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\jinja2\environment.py", line 857, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\jinja2\loaders.py", line 115, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\flask\templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "c:\Users\2ainm\anaconda3\envs\PyTF\lib\site-packages\flask\templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: isl-nba-main.html
# 127.0.0.1 - - [13/Dec/2023 18:58:00] "GET / HTTP/1.1" 500 -
